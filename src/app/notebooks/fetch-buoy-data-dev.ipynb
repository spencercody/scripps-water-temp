# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import sys
from pathlib import Path
project_folder = Path.cwd().parent.parent
sys.path.append(str(project_folder))
from modeling.utilities.utils_buoy_data import read_buoy_texts, collapse_to_daily, create_buoy_cols
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
buoy_data = 'https://www.ndbc.noaa.gov/data/realtime2/LJAC1.txt'

# %%
df = read_buoy_texts(buoy_data)

# %%
df.dtypes
# Out:
# YY      int64
# MM      int64
# DD      int64
# hh      int64
# mm      int64
# WDIR      str
# WSPD      str
# GST       str
# WVHT      str
# DPD       str
# APD       str
# MWD       str
# PRES      str
# ATMP      str
# WTMP      str
# DEWP      str
# VIS       str
# PTDY      str
# TIDE      str
# dtype: object

# %%
buoy_df = create_buoy_cols(df)
buoy_df.head(2)
# Out:
#         date  hh   WDIR  WSPD
# 0 2026-07-29  13  180.0   2.1
# 1 2026-07-29  13  160.0   1.5

# %%
buoy_df['WDIR'] = buoy_df.WDIR.astype(float, errors='ignore')
buoy_df['WSPD'] = buoy_df.WSPD.astype(float, errors='ignore')

# %%
df.WSPD.iloc[0]
# Out:
# '2.1'

# %%
daily_df = collapse_to_daily(buoy_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 daily_df = collapse_to_daily(df)
#
# File c:\Users\speco\USD\10_capstone\src\modeling\utilities\utils_buoy_data.py:77, in collapse_to_daily(buoy_df)
#      75 def collapse_to_daily(buoy_df):
#      76     daily_mean_buoy_data = (
# ---> 77         buoy_df.groupby(["date"])[["WSPD", "WDIR"]].mean().reset_index()
#      78     )
#      80     return daily_mean_buoy_data
#
# File c:\Users\speco\anaconda3\envs\ml_capstone\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
# ...
