# %% [markdown]
# # Transformer Model
# ### Weather and Water Temp Only Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sys
import joblib
import matplotlib.dates as mdates
from sklearn.metrics import  r2_score
import tensorflow as tf
# set up relative imports
project_folder = Path.cwd().parent.parent
sys.path.append(str(project_folder))

# %%
from modeling.model.transformer import Transformer, CustomSchedule, get_callbacks
from modeling.utilities.data_prep import setup_sequential_data, create_split_dfs

# %% [markdown]
# #### Read in the Data

# %%
data_folder = Path(r'..\..\data\model-ready\water-weather')

# train
train_X_df = pd.read_parquet(data_folder / 'scaled-X-train.parquet')
train_y_df = pd.read_parquet(data_folder / 'scaled-Y-train.parquet') # the Y data is not actually scaled inspite of the name

# test
test_X_df = pd.read_parquet(data_folder / 'scaled-X-test.parquet')
test_y_df = pd.read_parquet(data_folder / 'scaled-Y-test.parquet') # the Y data is not actually scaled inspite of the name

# val
val_X_df = pd.read_parquet(data_folder / 'scaled-X-val.parquet')
val_y_df = pd.read_parquet(data_folder / 'scaled-Y-val.parquet') # the Y data is not actually scaled inspite of the name

scaler = joblib.load(data_folder / 'minmax_scaler.joblib')

# %% [markdown]
# #### Set up sequential data

# %%
# train
train_X_df.reset_index(drop=True, inplace=True)
train_y_df.reset_index(drop=True, inplace=True)

# test
test_X_df.reset_index(drop=True, inplace=True)
test_y_df.reset_index(drop=True, inplace=True)

# val
val_X_df.reset_index(drop=True, inplace=True)
val_y_df.reset_index(drop=True, inplace=True)

# %%
seq_size = 10
X_train, y_train, y_idx_train = setup_sequential_data(train_X_df, train_y_df, seq_size)
X_val, y_val, y_idx_val =  setup_sequential_data(val_X_df, val_y_df, seq_size)
X_test, y_test, y_idx_test =  setup_sequential_data(test_X_df, test_y_df, seq_size)

# %% [markdown]
# ##### turn the dataframes into keras datasets

# %%
BATCH_SIZE = 32

train_dataset = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(1000)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

test_dataset = (
    tf.data.Dataset.from_tensor_slices((X_test, y_test))
    .batch(BATCH_SIZE)
)

# %% [markdown]
# ### Set up the transformer

# %%
num_layers = 4
d_model = 32
dff = 64
num_heads = 4
dropout_rate = 0.1

transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    dropout_rate=dropout_rate
    )

# %%
dummy = tf.zeros((1, X_train.shape[-2], X_train.shape[-1]))
transformer(dummy)
transformer.summary()
# Out:
# Model: "transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Encoder)               │ ?                      │        85,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Decoder)               │ ?                      │       152,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (1, 1)                 │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 237,537 (927.88 KB)
#  Trainable params: 237,537 (927.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
learning_rate = CustomSchedule(d_model) # this thing is overkill imo

optimizer = tf.keras.optimizers.Adam(learning_rate,
                                     beta_1=0.9,
                                     beta_2=0.98,
                                     epsilon=1e-9
                                     )

# %%
transformer.compile(
    loss='mse',
    #optimizer=optimizer,
    optimizer='adam',
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        ]
    )
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = transformer.fit(train_dataset,
                          epochs=50,
                          validation_data=val_dataset,
                          callbacks=get_callbacks()
                )
# Out:
# Epoch 1/50
# c:\Users\speco\anaconda3\envs\ml_capstone\Lib\site-packages\keras\src\trainers\epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 148s 98ms/step - loss: 14.8576 - mean_absolute_error: 2.4510 - val_loss: 0.7025 - val_mean_absolute_error: 0.6215 - learning_rate: 0.0010
# Epoch 2/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 55s 80ms/step - loss: 0.5795 - mean_absolute_error: 0.5567 - val_loss: 0.4485 - val_mean_absolute_error: 0.4862 - learning_rate: 0.0010
# Epoch 3/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 64s 92ms/step - loss: 0.5028 - mean_absolute_error: 0.5119 - val_loss: 0.4600 - val_mean_absolute_error: 0.5110 - learning_rate: 0.0010
# Epoch 4/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 72s 104ms/step - loss: 0.4881 - mean_absolute_error: 0.5065 - val_loss: 0.5955 - val_mean_absolute_error: 0.6109 - learning_rate: 0.0010
# Epoch 5/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 106s 139ms/step - loss: 0.4292 - mean_absolute_error: 0.4618 - val_loss: 0.5568 - val_mean_absolute_error: 0.5734 - learning_rate: 5.0000e-04
# Epoch 6/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 110s 159ms/step - loss: 0.4272 - mean_absolute_error: 0.4623 - val_loss: 0.4548 - val_mean_absolute_error: 0.4955 - learning_rate: 5.0000e-04
# Epoch 7/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 131s 189ms/step - loss: 0.4066 - mean_absolute_error: 0.4448 - val_loss: 0.3844 - val_mean_absolute_error: 0.4438 - learning_rate: 2.5000e-04
# Epoch 8/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 122s 177ms/step - loss: 0.4066 - mean_absolute_error: 0.4469 - val_loss: 0.3736 - val_mean_absolute_error: 0.4325 - learning_rate: 2.5000e-04
# Epoch 9/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 134s 194ms/step - loss: 0.4089 - mean_absolute_error: 0.4475 - val_loss: 0.4320 - val_mean_absolute_error: 0.4897 - learning_rate: 2.5000e-04
# Epoch 10/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 247s 346ms/step - loss: 0.4089 - mean_absolute_error: 0.4479 - val_loss: 0.4111 - val_mean_absolute_error: 0.4695 - learning_rate: 2.5000e-04
# Epoch 11/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 268s 387ms/step - loss: 0.3891 - mean_absolute_error: 0.4322 - val_loss: 0.3737 - val_mean_absolute_error: 0.4346 - learning_rate: 1.2500e-04
# Epoch 12/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 135s 196ms/step - loss: 0.3915 - mean_absolute_error: 0.4338 - val_loss: 0.4053 - val_mean_absolute_error: 0.4651 - learning_rate: 1.2500e-04
# Epoch 13/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 126s 182ms/step - loss: 0.3825 - mean_absolute_error: 0.4263 - val_loss: 0.3762 - val_mean_absolute_error: 0.4314 - learning_rate: 6.2500e-05
# Epoch 14/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 121s 175ms/step - loss: 0.3824 - mean_absolute_error: 0.4264 - val_loss: 0.3821 - val_mean_absolute_error: 0.4441 - learning_rate: 6.2500e-05
# Epoch 15/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 110s 159ms/step - loss: 0.3764 - mean_absolute_error: 0.4219 - val_loss: 0.3648 - val_mean_absolute_error: 0.4260 - learning_rate: 3.1250e-05
# Epoch 16/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 130s 188ms/step - loss: 0.3770 - mean_absolute_error: 0.4216 - val_loss: 0.3714 - val_mean_absolute_error: 0.4341 - learning_rate: 3.1250e-05
# Epoch 17/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 104s 150ms/step - loss: 0.3761 - mean_absolute_error: 0.4209 - val_loss: 0.3693 - val_mean_absolute_error: 0.4318 - learning_rate: 3.1250e-05
# Epoch 18/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 106s 154ms/step - loss: 0.3739 - mean_absolute_error: 0.4192 - val_loss: 0.3678 - val_mean_absolute_error: 0.4301 - learning_rate: 1.5625e-05
# Epoch 19/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 121s 175ms/step - loss: 0.3738 - mean_absolute_error: 0.4192 - val_loss: 0.3642 - val_mean_absolute_error: 0.4254 - learning_rate: 1.5625e-05
# Epoch 20/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 110s 160ms/step - loss: 0.3729 - mean_absolute_error: 0.4189 - val_loss: 0.3642 - val_mean_absolute_error: 0.4261 - learning_rate: 1.5625e-05
# Epoch 21/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 108s 157ms/step - loss: 0.3733 - mean_absolute_error: 0.4195 - val_loss: 0.3641 - val_mean_absolute_error: 0.4259 - learning_rate: 1.5625e-05
# Epoch 22/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 109s 157ms/step - loss: 0.3723 - mean_absolute_error: 0.4186 - val_loss: 0.3661 - val_mean_absolute_error: 0.4286 - learning_rate: 1.5625e-05
# Epoch 23/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 104s 151ms/step - loss: 0.3725 - mean_absolute_error: 0.4188 - val_loss: 0.3705 - val_mean_absolute_error: 0.4331 - learning_rate: 1.5625e-05
# Epoch 24/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 101s 145ms/step - loss: 0.3717 - mean_absolute_error: 0.4181 - val_loss: 0.3644 - val_mean_absolute_error: 0.4263 - learning_rate: 7.8125e-06
# Epoch 25/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 118s 171ms/step - loss: 0.3716 - mean_absolute_error: 0.4180 - val_loss: 0.3666 - val_mean_absolute_error: 0.4293 - learning_rate: 7.8125e-06
# Epoch 26/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 113s 164ms/step - loss: 0.3711 - mean_absolute_error: 0.4175 - val_loss: 0.3637 - val_mean_absolute_error: 0.4251 - learning_rate: 3.9063e-06
# Epoch 27/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 106s 153ms/step - loss: 0.3712 - mean_absolute_error: 0.4175 - val_loss: 0.3644 - val_mean_absolute_error: 0.4265 - learning_rate: 3.9063e-06
# Epoch 28/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 120s 174ms/step - loss: 0.3711 - mean_absolute_error: 0.4177 - val_loss: 0.3638 - val_mean_absolute_error: 0.4251 - learning_rate: 3.9063e-06
# Epoch 29/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 120s 173ms/step - loss: 0.3713 - mean_absolute_error: 0.4174 - val_loss: 0.3641 - val_mean_absolute_error: 0.4257 - learning_rate: 1.9531e-06
# Epoch 30/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 96s 140ms/step - loss: 0.3714 - mean_absolute_error: 0.4178 - val_loss: 0.3641 - val_mean_absolute_error: 0.4256 - learning_rate: 1.9531e-06
# Epoch 31/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 90s 131ms/step - loss: 0.3720 - mean_absolute_error: 0.4177 - val_loss: 0.3649 - val_mean_absolute_error: 0.4269 - learning_rate: 1.0000e-06
# Epoch 32/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 92s 134ms/step - loss: 0.3720 - mean_absolute_error: 0.4179 - val_loss: 0.3649 - val_mean_absolute_error: 0.4270 - learning_rate: 1.0000e-06
# Epoch 33/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 95s 137ms/step - loss: 0.3721 - mean_absolute_error: 0.4179 - val_loss: 0.3651 - val_mean_absolute_error: 0.4272 - learning_rate: 1.0000e-06
# Epoch 34/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 82s 119ms/step - loss: 0.3721 - mean_absolute_error: 0.4179 - val_loss: 0.3650 - val_mean_absolute_error: 0.4271 - learning_rate: 1.0000e-06
# Epoch 35/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 90s 130ms/step - loss: 0.3720 - mean_absolute_error: 0.4180 - val_loss: 0.3648 - val_mean_absolute_error: 0.4268 - learning_rate: 1.0000e-06
# Epoch 36/50
# 691/691 ━━━━━━━━━━━━━━━━━━━━ 90s 131ms/step - loss: 0.3718 - mean_absolute_error: 0.4178 - val_loss: 0.3650 - val_mean_absolute_error: 0.4270 - learning_rate: 1.0000e-06

# %% [markdown]
# ### Model Evalutation

# %%
y_pred = transformer.predict(test_dataset)
# Out:
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step

# %%
test_x_unscaled = scaler.inverse_transform(test_X_df)
test_x_df = pd.DataFrame(columns=test_X_df.columns, data=test_x_unscaled)

# %%
results_df = pd.DataFrame({
    'actual': y_test,
    'predicted': y_pred.flatten()
}, index=y_idx_test)

# %%
test_x_df = test_x_df.join(results_df,
                how='inner')

# %%
test_x_df['date'] = pd.to_datetime(test_x_df[['year','month','day']].astype(int), errors='coerce')

# %%
test_x_df['errors'] = test_x_df.predicted - test_x_df.actual

# %%
test_x_df.head(2)
# Out:
#     TMAX  TMIN  PRCP  BOT_TEMP_C  SURF_TEMP_C  month   day    year     tmax_c  \
# 9   73.0  44.0   0.0        12.9         14.1    1.0  17.0  2013.0  22.777778
# 10  73.0  48.0   0.0        12.9         13.1    1.0  18.0  2013.0  22.777778
#
#       tmin_c  sin_month  cos_month   sin_day   cos_day  past_10_day_ave_temp  \
# 9   6.666667        0.5   0.866025 -0.299363 -0.954139                 13.16
# 10  8.888889        0.5   0.866025 -0.485302 -0.874347                 13.12
#
#     past_10_day_std_temp  actual  predicted       date    errors
# 9               0.560159    13.1  13.670506 2013-01-17  0.570506
# 10              0.547317    13.7  13.337277 2013-01-18 -0.362723

# %%
plt.hist(test_x_df.errors, bins='auto')
plt.title('Transformer Test Error')
plt.xlabel('Error (\u00b0C)', fontsize=16)
plt.show()

# %%
pd.DataFrame(test_x_df.errors.abs().describe()).T.round(3)
# Out:
#          count   mean    std  min    25%    50%    75%    max
# errors  4731.0  0.503  0.508  0.0  0.152  0.351  0.679  4.222

# %%
plot_df = test_x_df[:30].copy()
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(plot_df.date, 
        plot_df.actual,
        label='True', 
        color='cornflowerblue'
        )
ax.plot(plot_df.date, 
        plot_df.predicted, 
        label='Predicted', 
        color='firebrick'
        )
ax.set_ylabel('Temperature (\u00b0C)', 
              fontsize=16
              )
ax.set_xlabel('Date', 
              fontsize=16
              )
ax.set_title('Transformer | Example Prediction', fontsize=18)
ax.legend()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
ax.tick_params(axis='x', labelrotation=45)
fig.text(.9, -.05, f'{int(plot_df.year.unique()[0])}')
plt.show()

# %%
mse = np.mean([x**2 for x in test_x_df.errors])
rmse = np.sqrt(mse)
r_2 = r2_score(y_test, y_pred)

print(f'RMSE = {round(rmse, 3)}')
print(f'r2 score = {round(r_2, 3)}')
# Out:
# RMSE = 0.715
# r2 score = 0.934

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\speco\\USD\\10_capstone\\src\\modeling\\notebooks'

# %%
# save the model
transformer.save('saved-models/transformer-1.keras')

# %%
# from tensorflow import keras
# from modeling.model.transformer import (
#     Transformer, Encoder, Decoder, EncoderLayer, DecoderLayer,
#     PositionalEmbedding, BaseAttention, CrossAttention,
#     GlobalSelfAttention, CausalSelfAttention, FeedForward
# )

# model = keras.models.load_model(
#     "saved-models/transformer-1.keras",
#     custom_objects={
#         "Transformer": Transformer,
#         "Encoder": Encoder,
#         "Decoder": Decoder,
#         "EncoderLayer": EncoderLayer,
#         "DecoderLayer": DecoderLayer,
#         "PositionalEmbedding": PositionalEmbedding,
#         "BaseAttention": BaseAttention,
#         "CrossAttention": CrossAttention,
#         "GlobalSelfAttention": GlobalSelfAttention,
#         "CausalSelfAttention": CausalSelfAttention,
#         "FeedForward": FeedForward,
#     }
# )
# Out:
# WARNING:tensorflow:From c:\Users\speco\anaconda3\envs\ml_capstone\Lib\site-packages\keras\src\backend\tensorflow\core.py:233: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
y_pred = model.predict(test_dataset)
# Out:
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 40s 195ms/step

# %%
lin
